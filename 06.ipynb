# %%
# %run util.ipynb

# %%
t = "turn on 0,0 through 999,999"

# %%
import re

# %%
digits = re.compile(r"\d+")
def parse(l):
    x1,y1,x2,y2 = [int(d) for d in digits.findall(t)] 
    return t[:7], x1,y1,x2,y2

# %%
instr = {
    "turn on": lambda cur: True,
    "turn of": lambda cur: False,
    "toggle ": lambda cur: not cur
}

# %%
grid = np.zeros((1000,1000), dtype=bool)
for t in get_puzzle(6):
    inst, x1,y1,x2,y2 = parse(t)
    for x in range(x1,x2+1):
        for y in range(y1,y2+1):
            grid[x,y] = instr[inst](grid[x,y])

# %%
plt.imshow(grid)

# %%
sum(sum(grid))
# Out:
# 543903

# %%
instr = {
    "turn on": lambda cur: cur+1,
    "turn of": lambda cur: max(0,cur-1),
    "toggle ": lambda cur: cur + 2
}

# %%
grid = np.zeros((1000,1000), dtype=int)
for t in get_puzzle(6):
    inst, x1,y1,x2,y2 = parse(t)
    for x in range(x1,x2+1):
        for y in range(y1,y2+1):
            grid[x,y] = instr[inst](grid[x,y])

# %%
plt.imshow(grid)

# %%
sum(sum(grid))
# Out:
# 14687245
